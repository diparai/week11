# %%
import pandas as pd
import urllib.request
import json
from pandas.io.json import json_normalize

# %%
api_key = 'oZph42Fhh9oZqSxPWDEcA55QyWge54A9'
web_url = 'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?'
request = web_url+'&api-key='+api_key
response = str(urllib.request.urlopen(request).read(), 'utf-8')

# Lets convert web_data into a dataframe

bestseller_books = json.loads(response)
bestseller_books
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'num_results': 34063,
#  'results': [{'title': '"I GIVE YOU MY BODY ..."',
#    'description': 'The author of the Outlander novels gives tips on writing sex scenes, drawing on examples from the books.',
#    'contributor': 'by Diana Gabaldon',
#    'author': 'Diana Gabaldon',
#    'contributor_note': '',
#    'price': '0.00',
#    'age_group': '',
#    'publisher': 'Dell',
#    'isbns': [{'isbn10': '0399178570', 'isbn13': '9780399178573'}],
#    'ranks_history': [{'primary_isbn10': '0399178570',
#      'primary_isbn13': '9780399178573',
#      'rank': 8,
#      'list_name': 'Advice How-To and Miscellaneous',
#      'display_name': 'Advice, How-To & Miscellaneous',
#      'published_date': '2016-09-04',
#      'bestsellers_date': '2016-08-20',
#      'weeks_on_list': 1,
#      'rank_last_week': 0,
#      'asterisk': 0,
#      'dagger': 0}],
# ...

# %%
DF = pd.DataFrame(data=bestseller_books['results'])
DF.head()
# Out:
#                               title  \
# 0          "I GIVE YOU MY BODY ..."
# 1  "MOST BLESSED OF THE PATRIARCHS"
# 2                       #ASKGARYVEE
# 3                         #GIRLBOSS
# 4                       #IMOMSOHARD
#
#                                          description  \
# 0  The author of the Outlander novels gives tips ...
# 1  A character study that attempts to make sense ...
# 2  The entrepreneur expands on subjects addressed...
# 3  An online fashion retailer traces her path to ...
# 4
#
#                                 contributor  \
# 0                         by Diana Gabaldon
# 1  by Annette Gordon-Reed and Peter S. Onuf
# 2                        by Gary Vaynerchuk
# 3                         by Sophia Amoruso
# 4        by Kristin Hensley and Jen Smedley
#
#                                  author contributor_note price age_group  \
# 0                        Diana Gabaldon                   0.00
# ...
